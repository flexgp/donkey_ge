# %%
import json
import os
# Change working directory to the root of the repository (assumes notebook working directory is `tutorials`)
os.chdir('..')
import main
from fitness.program_synthesis.dijkstra import Dijkstra

# %% [markdown]
# # Run Program Synthesis

# %%
data_file = "tests/program_synthesis/Dijkstra.json"
with open(data_file, "r") as f:
    data = json.load(f)

# %%
program_synthesis = Dijkstra(data["train"], "")
code = """0,1,2,3"""
result = program_synthesis.run(code)
print(result)
# assert sum(result) == 500
# Out:
# Run program:
#
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0,1,2,3]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
#
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
out_path = 'tmp'
args = ["-o", out_path, "-f", "tests/configurations/dijkstra.yml"]
_ = main.main(args)
# Out:
# Setting random seed: 1 0.13436
# donkey_ge settings: {'population_size': 10, 'max_length': 5, 'elite_size': 1, 'generations': 20, 'tournament_size': 2, 'seed': 1, 'crossover_probability': 0.8, 'mutation_probability': 0.1, 'codon_size': 127, 'integer_input_element_max': 1000, 'bnf_grammar': 'tests/grammars/bfs.bnf', 'fitness_function': {'name': 'fitness.fitness.ProgramSynthesis', 'data': 'tests/program_synthesis/Dijkstra.json', 'synthesis_problem': 'fitness.program_synthesis.dijkstra.Dijkstra', 'code_template_path': 'tests/program_synthesis/code_template_dijkstra.txt'}, 'output_dir': 'tmp', 'coev': False}
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 1, 2, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 3, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 0, 3, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 1, 2, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 2, 0, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 0, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 1, 3, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 3, 2, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 1, 1, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 1, 0, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:0 t:0.014 fit_ave:69.50+-27.983 size_ave:4.00+-0.000 length_ave:5.00+-0.000 Ind: 3, 0, 3, 2,; 94
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 0, 3, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 3, 0, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 0, 1, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 2, 0, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 1, 0, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:1 t:0.004 fit_ave:90.30+-3.100 size_ave:4.00+-0.000 length_ave:5.60+-0.917 Ind: 1, 0, 1, 3,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 1, 0, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 2, 2, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 1, 3, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 0, 1, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 1, 1, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 2, 0, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:2 t:0.004 fit_ave:82.20+-18.856 size_ave:4.00+-0.000 length_ave:5.80+-1.077 Ind: 1, 0, 1, 3,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 3, 1, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 1, 1, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 0, 1, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 2, 3, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 1, 0, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 1, 1, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:3 t:0.011 fit_ave:85.30+-19.754 size_ave:4.00+-0.000 length_ave:5.60+-0.917 Ind: 3, 0, 1, 3,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 1, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 0, 1, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 2, 2, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 0, 1, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 2, 0, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 2, 3, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 1, 1, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:4 t:0.009 fit_ave:85.30+-19.728 size_ave:4.00+-0.000 length_ave:6.10+-1.221 Ind: 1, 0, 1, 3,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 1, 2, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 0, 0, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 0, 1, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 1, 1, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 0, 1, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 1, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:5 t:0.005 fit_ave:86.40+-19.906 size_ave:4.00+-0.000 length_ave:7.00+-1.000 Ind: 1, 0, 1, 2,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 1, 3, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 1, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 1, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 0, 2, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:6 t:0.003 fit_ave:94.30+-1.487 size_ave:4.00+-0.000 length_ave:7.70+-1.792 Ind: 0, 1, 3, 0,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 2, 3, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 0, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 1, 2, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 2, 2, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:7 t:0.003 fit_ave:79.80+-26.615 size_ave:4.00+-0.000 length_ave:7.60+-2.010 Ind: 1, 0, 1, 2,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 0, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 0, 3, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 3, 1, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 1, 3, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 0, 0, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 3, 0, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:8 t:0.005 fit_ave:86.20+-20.024 size_ave:4.00+-0.000 length_ave:8.50+-2.579 Ind: 0, 1, 1, 3,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 0, 3, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 1, 1, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:9 t:0.002 fit_ave:94.60+-0.490 size_ave:4.00+-0.000 length_ave:9.40+-1.855 Ind: 1, 0, 1, 2,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 0, 2, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 0, 2, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:10 t:0.002 fit_ave:93.40+-2.458 size_ave:4.00+-0.000 length_ave:9.70+-1.792 Ind: 1, 0, 1, 2,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 1, 2, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 0, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 1, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 2, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 1, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([1, 2, 1, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:11 t:0.006 fit_ave:85.70+-19.708 size_ave:4.00+-0.000 length_ave:8.80+-1.833 Ind: 0, 0, 1, 2,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 2, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 2, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 1, 3, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:12 t:0.002 fit_ave:93.80+-1.939 size_ave:4.00+-0.000 length_ave:8.50+-2.335 Ind: 0, 1, 3, 3,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 2, 1, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 0, 0, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:13 t:0.001 fit_ave:94.30+-1.487 size_ave:4.00+-0.000 length_ave:8.80+-2.638 Ind: 0, 2, 1, 0,; 95
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 1, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 2, 0, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 2, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:14 t:0.003 fit_ave:94.60+-2.059 size_ave:4.00+-0.000 length_ave:10.60+-3.007 Ind: 0, 3, 1, 2,; 99
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 2, 2, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 2, 1, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 2, 3, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 2, 0, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 0, 1, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:15 t:0.004 fit_ave:94.40+-3.040 size_ave:4.00+-0.000 length_ave:10.30+-2.900 Ind: 0, 3, 1, 2,; 99
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 1, 0,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 2, 3, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([3, 2, 1, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:16 t:0.003 fit_ave:95.80+-3.682 size_ave:4.00+-0.000 length_ave:9.60+-2.800 Ind: 0, 3, 1, 2,; 99
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 3, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:17 t:0.001 fit_ave:97.30+-2.100 size_ave:4.00+-0.000 length_ave:12.10+-1.700 Ind: 0, 3, 1, 2,; 99
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 3, 1, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 2, 1, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 1, 2, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 3, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([2, 3, 1, 1,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:18 t:0.003 fit_ave:89.60+-21.068 size_ave:4.00+-0.000 length_ave:12.20+-1.470 Ind: 0, 3, 1, 2,; 99
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 0, 2,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 3, 2, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Run program:
# def find_shortest_distance(adj, s):
#         d = [0,100000, 100000, 10000]
#         for i in ([0, 1, 2, 3,]):
#             for j in ([0,1,2,3]):
#                 if d[i] + adj[i][j] < d[j]:
#                     d[j] = d[i] + adj[i][j]
#         return d[s]
#
# outcomes = evaluate_exemplars(inputs, outputs, find_shortest_distance)
# Gen:19 t:0.003 fit_ave:96.60+-2.615 size_ave:4.00+-0.000 length_ave:13.20+-2.272 Ind: 0, 1, 2, 3,; 100
# Cache entries:89 Total Fitness Evaluations:2000 Fitness Values:8
# Time: 0.110 Best solution:Ind: 0, 1, 2, 3,; 100

# %%
from util.plot_donkey_ge import plot_fitness
# Plot fitness from a search
plot_fitness(out_path=out_path, in_path=out_path)
