# %%
import json
import os
# Change working directory to the root of the repository (assumes notebook working directory is `tutorials`)
os.chdir('..')
import main
from fitness.program_synthesis.parenthesis_matching import ParenthesisMatching

# %% [markdown]
# # Run Program Synthesis

# %%
data_file = "tests/program_synthesis/ParenthesisMatching.json"
with open(data_file, "r") as f:
    data = json.load(f)

# %%
program_synthesis = ParenthesisMatching(data["train"], "")
code = """
        self.increment = 1
        self.decrement = 1
        self.check = 0
        left = 0
        for i in inputs:
            if i == "(":
                left += self.increment
            elif left == self.check:
                return False
            else:
                left -= self.decrement
        return left == self.check
    """
result = program_synthesis.run(code)
print(result)
assert sum(result) == 500
# Out:
# aewugwaygfu
# Run program:
#
# class Cls:
#
#     def __init__(self):
#         self.increment = 0
#         self.decrement = 0
#         self.check = 0
#
#     def fcn(self, inputs):
#
#         self.increment = 1
#         self.decrement = 1
#         self.check = 0
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls()
# outcomes = instance.run(inputs, outputs)
#
# From exec:
# Solver model:[]
#
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
out_path = 'tmp'
args = ["-o", out_path, "-f", "tests/configurations/parenthesis_matching.yml"]
_ = main.main(args)
# Out:
# Setting random seed: 1 0.13436
# donkey_ge settings: {'population_size': 10, 'max_length': 5, 'elite_size': 1, 'generations': 3, 'tournament_size': 2, 'seed': 1, 'crossover_probability': 0.8, 'mutation_probability': 0.1, 'codon_size': 127, 'integer_input_element_max': 1000, 'bnf_grammar': 'tests/grammars/parenthesis_matching.bnf', 'fitness_function': {'name': 'fitness.fitness.ProgramSynthesis', 'data': 'tests/program_synthesis/ParenthesisMatching.json', 'synthesis_problem': 'fitness.program_synthesis.parenthesis_matching.ParenthesisMatching', 'code_template_path': 'tests/program_synthesis/code_template_parenthesis_matching.txt'}, 'output_dir': 'tmp', 'coev': False}
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(0, -1, 0)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(-2, 0, 2)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(0, 1, 0)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(2, 2, 2)
# outcomes = instance.run(inputs, outputs)
#
# From exec:
# Solver model:[]
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(1, 0, -2)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(2, -2, 0)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(-2, -1, 0)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(2, 2, -1)
# outcomes = instance.run(inputs, outputs)
#
# From exec:
# Solver model:[]
#
# Gen:0 t:0.233 fit_ave:94.70+-189.482 size_ave:3.00+-0.000 length_ave:5.00+-0.000 Ind: 2, 2, -1; 486
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(2, 2, -2)
# outcomes = instance.run(inputs, outputs)
#
# From exec:
# Solver model:[]
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(-1, 1, -1)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(0, 2, 2)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(2, -2, -2)
# outcomes = instance.run(inputs, outputs)
#
# Gen:1 t:0.097 fit_ave:192.50+-235.821 size_ave:3.00+-0.000 length_ave:5.10+-0.831 Ind: 2, 2, -1; 486
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(-2, 0, -1)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(2, -2, -1)
# outcomes = instance.run(inputs, outputs)
#
# aewugwaygfu
# Run program:
# class Cls:
#
#     def __init__(self, increment, decrement, check):
#         self.increment = increment
#         self.decrement = decrement
#         self.check = check
#
#     def fcn(self, inputs):
#         left = 0
#         for i in inputs:
#             if i == "(":
#                 left += self.increment
#             elif left == self.check:
#                 return False
#             else:
#                 left -= self.decrement
#         return left == self.check
#
#
#     def run(self, inputs, outputs):
#         self.outcomes = evaluate_exemplars(inputs, outputs, self)
#         return self.outcomes
#
# instance = Cls(2, 1, 0)
# outcomes = instance.run(inputs, outputs)
#
# Gen:2 t:0.067 fit_ave:333.30+-218.409 size_ave:3.00+-0.000 length_ave:5.20+-0.872 Ind: 2, 2, -1; 486
# Cache entries:15 Total Fitness Evaluations:300 Fitness Values:4
# Time: 0.429 Best solution:Ind: 2, 2, -1; 486

# %%
from util.plot_donkey_ge import plot_fitness
# Plot fitness from a search
plot_fitness(out_path=out_path, in_path=out_path)
